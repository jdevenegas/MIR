# %%
from code.data_utils import get_token, get_auth_header, get_artist_albums, get_album_tracks, get_artist_tracks, get_audio_features
from code.analysis import normalize_audio_feats
import pandas as pd
import numpy as np

token=get_token()
print(token)
# Out:
# 5835805e22a345948373bd954162324c 41b27d9b0cbe44deb1d9edd7d306160d
# BQBqrSN1KXVUrCKMHjbosRXVAlQvQqtjoSGM5R9TXcgZ7nVf00vgS9rsT6JKHiQSGFC0gf7ouNLanZF9-BGPsJiJ6quAku9tBBitwHRmTgY-8wUhN3s

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

# Define the circle of fifths order
CIRCLE_OF_FIFTHS = [0, 7, 2, 9, 4, 11, 6, 1, 8, 3, 10, 5]

# Create a mapping from pitch classes to their positions in the circle of fifths
PITCH_CLASS_TO_POSITION = {pc: idx for idx, pc in enumerate(CIRCLE_OF_FIFTHS)}

# Number of pitch classes
N_PITCH_CLASSES = len(CIRCLE_OF_FIFTHS)

# Calculate the angle for each pitch class
ANGLES = {pc: (2 * np.pi * idx) / N_PITCH_CLASSES for pc, idx in PITCH_CLASS_TO_POSITION.items()}

def angle_to_vector(angle):
    return np.array([np.cos(angle), np.sin(angle)])

# Create vectors for each pitch class
PITCH_CLASS_VECTORS = {pc: angle_to_vector(angle) for pc, angle in ANGLES.items()}

# def cosine_similarity(vec1, vec2):
#     return np.dot(vec1, vec2) / (norm(vec1) * norm(vec2))

def normalize_cosine_similarity(cosine_similarity):
    """
    Normalize cosine similarity from [-1, 1] to [0, 1].
    """
    return (cosine_similarity + 1) / 2
    

def normalize_audio_feats(feats_df, tempo_factor = 1, include_categorical=True, circle_5 = True):
    # Normalize continuous features
    scaler = MinMaxScaler()
    continuous_features = ['tempo', 'valence', 'liveness', 'instrumentalness', 'acousticness', 'speechiness', 'loudness', 'energy', 'danceability']
    # feats_df[continuous_features] = scaler.fit_transform(feats_df[continuous_features])
    scaler.fit(feats_df[continuous_features])
    feats_df.tempo = tempo_factor*feats_df.tempo
    feats_df[continuous_features] = scaler.transform(feats_df[continuous_features])

    # Encode categorical features
    if include_categorical:
        if circle_5: 
            categorical_encoded = np.array([PITCH_CLASS_VECTORS[k] for k in feats_df['key'].tolist()])
            categorical_encoded_df = pd.DataFrame(categorical_encoded)
            categorical_encoded_df.columns = ['C5_0', 'C5_1']
        else:
            encoder = OneHotEncoder(sparse_output=False)
            categorical_features = feats_df[['key']]
            categorical_encoded = encoder.fit_transform(categorical_features)
            categorical_encoded_df = pd.DataFrame(categorical_encoded)
        
        # # Combine all features
        feats_df = pd.concat([feats_df[continuous_features], categorical_encoded_df], axis=1)
    # print(feats_df)    
    # scaler = MinMaxScaler()
    # feats_df = pd.DataFrame(scaler.fit_transform(feats_df))
    # feats_df.columns = continuous_features+['C5_0', 'C5_1']
    # print(feats_df)
    return feats_df

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

def compare_discog(audio_feats_df_1, audio_feats_df_2, include_categorical=True, circle_5 = True):
    # n_seeds = len(audio_feats_df_1)
    # audio_feats_df = pd.concat([audio_feats_df_1, audio_feats_df_2], axis=0, ignore_index=True)
    norm_audio_feats_df_1 = normalize_audio_feats(audio_feats_df_1.copy(), 1, include_categorical, circle_5)
    norm_audio_feats_df_2 = normalize_audio_feats(audio_feats_df_2.copy(), 1, include_categorical, circle_5)
    d_1 = cosine_similarity(norm_audio_feats_df_1, norm_audio_feats_df_2)
    # print(audio_feats_df_1.tempo)
    
    norm_audio_feats_df_1 = normalize_audio_feats(audio_feats_df_1.copy(), 0.5, include_categorical, circle_5)
    d_2 = cosine_similarity(norm_audio_feats_df_1, norm_audio_feats_df_2)

    norm_audio_feats_df_1 = normalize_audio_feats(audio_feats_df_1.copy(), 2, include_categorical, circle_5)
    d_3 = cosine_similarity(norm_audio_feats_df_1, norm_audio_feats_df_2)
    
    # d_max = np.max(d, axis=1)
    return d_1, d_2, d_3

# %%
def get_album_tracks(token, album_id, summarize=False):
    url = os.path.join(ROOT_API_URL, f"albums/{album_id}/tracks")
    headers = get_auth_header(token)
    result = get(url, headers=headers)
    js_result = json.loads(result.content)
    print(js_result)
    tracks_info = js_result['items']
    # track_name = [t['name'] for t in tracks_info]
    # track_id = [t['id'] for t in tracks_info]
    track_artists = [t['artists'] for t in tracks_info]
    
    if summarize:
        select_track_keys = ['name', 'id']
        select_artist_keys = ['name', 'id']
        track_ls = [{'track_%s'%k: t[k] for k in select_track_keys} for t in tracks_info]
        artist_ls = [{'artist_%s'%k: a[0][k] for k in select_artist_keys} for a in track_artists]
            
        tracks_info = pd.DataFrame([{**a, **t} for a, t in zip(artist_ls, track_ls)])
    return tracks_info

# %%
#Radiohead: https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb?si=blakDesXQYWlHpnLqdDwkQ
#Arcade Fire: https://open.spotify.com/artist/3kjuyTCjPG1WMFCiyc5IuB?si=2cnIfg3QS2WuK0QYrsqupA
#Future Islands: https://open.spotify.com/artist/1WvvwcQx0tj6NdDhZZ2zZz?si=ig_wF6OVTZSj6XOKsrdx_A
#DM - https://open.spotify.com/artist/762310PdDnwsDxAQxzQkfX?si=rJ18xcQdS_2drHgcSukRDg
#Kraftwerk: https://open.spotify.com/artist/0dmPX6ovclgOy8WWJaFEUU?si=rNgVC61lRdKrfVz88pvSZw

#Modest Mouse: https://open.spotify.com/artist/1yAwtBaoHLEDWAnWR87hBT?si=dlOVIWNVR8G8F-6qdePosw
#Police - https://open.spotify.com/artist/5NGO30tJxFlKixkPSgXcFE?si=rUyliCBOS8W8Cbh94AV1OA
#Beatles - https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2?si=PJiFfighQlOsD0pJXrZSLw

artist_id_1 = '3WrFJ7ztbogyGnTHbHJFl2'
tracks_df_1 = get_artist_tracks(token, artist_id_1, live_tracks=False)
tracks_df_1 = tracks_df_1[tracks_df_1.artist_id == artist_id_1].reset_index(drop=True)
tracks_df_1.head()
# Out:
# 0
# Next request in ~ 4 seconds
# Elapsed Time: 24.215622186660767 seconds
# Getting next 0 tracks
#    artist_name               artist_id  \
# 0  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 1  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 2  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 3  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 4  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
#
#                                          track_name                track_id
# 0              Strawberry Fields Forever - 2015 Mix  4JaTNsbucUxF3FtKqt3IY3
# 1                             Penny Lane - 2017 Mix  5M8s9X2vuW1tv52uv4meCt
# 2  Sgt. Pepper's Lonely Hearts Club Band - 2017 Mix  5GuGzaaKHoOR3amXgvT2Pq
# 3     With A Little Help From My Friends - 2017 Mix  0Q6YQlQHdFd6NfXjcHtijM
# 4          Lucy In The Sky With Diamonds - 2017 Mix  4GX8I8c7gMZn7mZFM9QAs0

# %%
# album_info = get_artist_albums(token, artist_id_1, offset=0, limit=50)
# album_name_ls = [a['name'] for a in album_info]
# album_id_ls = [a['id'] for a in album_info]
# tracks = []
# tracks += [get_album_tracks(token, album_id, summarize=True) for album_id in album_id_ls]

# %%
audio_feats_1 = get_audio_features(token, tracks_df_1.track_id.tolist())
audio_feats_df_1 = pd.DataFrame(audio_feats_1)
audio_feats_df_1 = audio_feats_df_1.loc[:,['tempo', 'valence', 'liveness', 'instrumentalness',
       'acousticness', 'speechiness', 'mode', 'loudness', 'key', 'energy',
       'danceability']]
audio_feats_df_1
# Out:
# 50
# request 1 - 50 tracks completed
# Next request in ~ 2 seconds
# Elapsed Time: 2.1941137313842773 seconds
# 100
# request 2 - 100 tracks completed
# Next request in ~ 4 seconds
# Elapsed Time: 6.705664396286011 seconds
# 150
# request 3 - 150 tracks completed
# Next request in ~ 3 seconds
# Elapsed Time: 9.795597076416016 seconds
# 200
# request 4 - 200 tracks completed
# Next request in ~ 4 seconds
# Elapsed Time: 14.12145709991455 seconds
# 250
# request 5 - 250 tracks completed
# Next request in ~ 2 seconds
# Elapsed Time: 16.255526542663574 seconds
# 300
# request 6 - 300 tracks completed
# Next request in ~ 5 seconds
# Elapsed Time: 21.412887811660767 seconds
# 350
# request 7 - 350 tracks completed
# Next request in ~ 3 seconds
# Elapsed Time: 25.39545440673828 seconds
# 400
# request 8 - 400 tracks completed
# Next request in ~ 1 seconds
# Elapsed Time: 27.255733489990234 seconds
# 450
# request 9 - 450 tracks completed
# Next request in ~ 3 seconds
# Elapsed Time: 30.987874507904053 seconds
# 500
# request 10 - 500 tracks completed
# Next request in ~ 3 seconds
# Elapsed Time: 34.46038341522217 seconds
# 521
# request 11 - 521 tracks completed
# Elapsed Time: 35.003660440444946 seconds
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 0     96.705    0.220    0.0918          0.000636       0.26900       0.2920
# 1    113.063    0.677    0.1230          0.003140       0.08980       0.0402
# 2     95.369    0.472    0.8940          0.035400       0.03780       0.1130
# 3    112.303    0.707    0.2560          0.000000       0.13000       0.0282
# 4    187.405    0.497    0.1270          0.000000       0.13000       0.0442
# ..       ...      ...       ...               ...           ...          ...
# 516  106.301    0.741    0.1480          0.000000       0.11300       0.0268
# 517  137.735    0.697    0.1900          0.000000       0.11700       0.0298
# 518  122.466    0.852    0.3230          0.000000       0.01570       0.0408
# 519  176.548    0.654    0.1050          0.004490       0.17300       0.0351
# 520  121.375    0.725    0.1080          0.000000       0.00903       0.0425
#
#      mode  loudness  key  energy  danceability
# 0       1    -8.727   10   0.665         0.389
# 1       1    -8.369    9   0.506         0.631
# 2       1    -7.866    7   0.837         0.360
# 3       1    -7.900    4   0.595         0.678
# 4       1    -6.921    2   0.537         0.247
# ..    ...       ...  ...     ...           ...
# 516     1   -10.061    2   0.608         0.382
# 517     0   -10.553    6   0.723         0.642
# 518     1    -8.636    2   0.569         0.753
# 519     1   -11.033    4   0.386         0.430
# 520     1    -9.308    4   0.628         0.534
#
# [521 rows x 11 columns]

# %%
#Kraftwerk: https://open.spotify.com/artist/0dmPX6ovclgOy8WWJaFEUU?si=rNgVC61lRdKrfVz88pvSZw
#Orchestral Manoeuvres In The Dark - https://open.spotify.com/artist/7wJ9NwdRWtN92NunmXuwBk?si=DkuYZqpkRM2xB-X9Xl1L8g
#The Cure - https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s?si=0wtCJ0DCQHKIe-Fb6zoNJg
#DM - https://open.spotify.com/artist/762310PdDnwsDxAQxzQkfX?si=rJ18xcQdS_2drHgcSukRDg
#Boy Harsher - https://open.spotify.com/artist/4iom7VVRU6AHRIu1JUXpLG?si=8mTRPDd2TryJi9XQ3MmDeA

#Pixies - https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT?si=UQflLGjYTq2MeyKqB2IGrg
#Killers - https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu?si=5k2jA9OQQLycx75Af14MeA
#2Door - #2door - https://open.spotify.com/artist/536BYVgOnRky0xjsPT96zl?si=It8JgQrzSoaj18F9nrvwWg

#Stick Figure - https://open.spotify.com/artist/5SXEylV07TC57eanSxxg4R?si=3YC-Jxk2TkK02b4kronYlg
#Slightly Stoopid - https://open.spotify.com/artist/6MxlVTY6PmY8Nyn16fvxtb?si=ozGq6h1_SJeaYJ7Rx2VeSQ
#Chemical Brothers - https://open.spotify.com/artist/1GhPHrq36VKCY3ucVaZCfo?si=ePxX0PI-QSyA_qvzf8JLUw

artist_id_2 = '1GhPHrq36VKCY3ucVaZCfo'
tracks_df_2 = get_artist_tracks(token, artist_id_2, live_tracks=False)
tracks_df_2 = tracks_df_2[tracks_df_2.artist_id == artist_id_2].reset_index(drop=True)
tracks_df_2.head()
# Out:
# 0
# Next request in ~ 2 seconds
# Elapsed Time: 31.249794483184814 seconds
# Getting next 20 tracks
# 50
# Next request in ~ 4 seconds
# Elapsed Time: 46.40679621696472 seconds
# Getting next 35 tracks
# 100
# Next request in ~ 2 seconds
# Elapsed Time: 68.50265955924988 seconds
# Getting next 0 tracks
#              artist_name               artist_id  \
# 0  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 1  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 2  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 3  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 4  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
#
#                      track_name                track_id
# 0                         Intro  6WGGymJloCXBL4BY4liTda
# 1  Live Again (feat. Halo Maud)  55djbD8EGJOd3akmGMXqw6
# 2                     No Reason  05viyiChBLJMuVup0mtH2A
# 3                       Goodbye  5Eyhw61L8qs4bdc6G4cfW3
# 4                     Fountains  6VBFpHKhpBDfpjAcSOISoH

# %%
audio_feats_2 = get_audio_features(token, tracks_df_2.track_id.tolist())
audio_feats_df_2 = pd.DataFrame(audio_feats_2)
audio_feats_df_2 = audio_feats_df_2.loc[:,['tempo', 'valence', 'liveness', 'instrumentalness',
       'acousticness', 'speechiness', 'mode', 'loudness', 'key', 'energy',
       'danceability']]
audio_feats_df_2
# Out:
# 50
# request 1 - 50 tracks completed
# Next request in ~ 4 seconds
# Elapsed Time: 4.717858791351318 seconds
# 100
# request 2 - 100 tracks completed
# Next request in ~ 1 seconds
# Elapsed Time: 6.4284093379974365 seconds
# 150
# request 3 - 150 tracks completed
# Next request in ~ 2 seconds
# Elapsed Time: 8.545787572860718 seconds
# 200
# request 4 - 200 tracks completed
# Next request in ~ 3 seconds
# Elapsed Time: 11.71789264678955 seconds
# 250
# request 5 - 250 tracks completed
# Next request in ~ 5 seconds
# Elapsed Time: 17.25292468070984 seconds
# 300
# request 6 - 300 tracks completed
# Next request in ~ 2 seconds
# Elapsed Time: 19.745505809783936 seconds
# 350
# request 7 - 350 tracks completed
# Next request in ~ 4 seconds
# Elapsed Time: 24.6468448638916 seconds
# 400
# request 8 - 400 tracks completed
# Next request in ~ 2 seconds
# Elapsed Time: 27.67387056350708 seconds
# 410
# request 9 - 410 tracks completed
# Elapsed Time: 28.25812077522278 seconds
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 0    126.973    0.354    0.0855             0.809      0.004840       0.0426
# 1    127.003    0.527    0.0779             0.341      0.000875       0.0752
# 2    128.039    0.495    0.1460             0.802      0.003040       0.0422
# 3    129.941    0.152    0.0829             0.333      0.020200       0.0556
# 4    107.020    0.509    0.2420             0.087      0.124000       0.0408
# ..       ...      ...       ...               ...           ...          ...
# 405  120.021    0.230    0.7380             0.295      0.007060       0.0827
# 406  127.001    0.363    0.1140             0.522      0.119000       0.0529
# 407  127.001    0.363    0.1140             0.522      0.119000       0.0529
# 408  124.964    0.735    0.4260             0.788      0.118000       0.0612
# 409  109.358    0.820    0.1070             0.330      0.021800       0.0638
#
#      mode  loudness  key  energy  danceability
# 0       0   -12.578    5   0.580         0.686
# 1       0    -5.440    6   0.897         0.550
# 2       1    -7.179    2   0.866         0.663
# 3       1    -5.714    1   0.894         0.539
# 4       1    -7.215    0   0.710         0.769
# ..    ...       ...  ...     ...           ...
# 405     1    -5.897    7   0.918         0.675
# 406     1    -4.976    2   0.921         0.632
# 407     1    -4.976    2   0.921         0.632
# 408     1   -10.995    7   0.939         0.614
# 409     1    -3.981    1   0.974         0.604
#
# [410 rows x 11 columns]

# %%
na_mask_1 = (audio_feats_df_1.isna().sum(1)==0).tolist()
print(len(audio_feats_df_1)-sum(na_mask_1))
if sum(na_mask_1) < len(audio_feats_df_1):
    tracks_df_1 = tracks_df_1[na_mask_1].reset_index(drop=True)
    audio_feats_df_1 = audio_feats_df_1[na_mask_1].reset_index(drop=True)

na_mask_2 = (audio_feats_df_2.isna().sum(1)==0).tolist()
print(len(audio_feats_df_2)-sum(na_mask_2))
if sum(na_mask_2) < len(audio_feats_df_2):
    tracks_df_2 = tracks_df_2[na_mask_2].reset_index(drop=True)
    audio_feats_df_2 = audio_feats_df_2[na_mask_1].reset_index(drop=True)
# Out:
# 0
# 0

# %%
S_1, S_2, S_3 = compare_discog(audio_feats_df_1.copy(), audio_feats_df_2.copy(), include_categorical=True, circle_5 = True)
S = np.maximum.reduce(np.array([S_1, S_2, S_3]))
# S = S_1

# %%
S_sub_sorted = np.sort(S, axis=1)[:,::-1][:,:10]
s_max = S_sub_sorted[:,0]
S_sub_sorted
# Out:
# array([[0.91978526, 0.89874405, 0.89874405, ..., 0.88464917, 0.88457708,
#         0.87986062],
#        [0.9843199 , 0.9384464 , 0.9384464 , ..., 0.92670108, 0.92412321,
#         0.92285859],
#        [0.94972252, 0.94611138, 0.94192211, ..., 0.91477284, 0.91477013,
#         0.89586502],
#        ...,
#        [0.95390781, 0.95035357, 0.94954626, ..., 0.93135687, 0.91899105,
#         0.91812912],
#        [0.91849443, 0.89896704, 0.89832762, ..., 0.88624942, 0.88461875,
#         0.88149913],
#        [0.94791639, 0.93895741, 0.93458209, ..., 0.93320478, 0.93320478,
#         0.93320478]])

# %%
s_max_ix1 = np.argsort(s_max)[::-1]
s_max_ix1
# Out:
# array([101, 208, 233,  94, 105, 498, 410, 405, 331, 508, 340, 399, 444,
#        294,  60, 313, 136, 517, 219, 189, 258, 145,   1,  61, 238, 376,
#        460, 366, 174,  54, 293, 479,  67, 112, 306,  33,  19, 244, 375,
#        264, 334,  71, 188,  86,  69,  50, 139, 150,  78, 413, 179,  96,
#        476,  52, 372,  58, 445,  36, 457, 390, 401, 191, 403, 172, 271,
#        256,  35,  51, 183, 434, 220, 286, 246,  93, 393,  12, 311, 474,
#         84, 304, 198, 300, 449, 407, 298,  77, 117, 291, 324, 511, 400,
#         55, 329, 104, 510, 384, 111, 338, 339, 180, 514, 327, 303, 302,
#         16, 144, 147, 439,  26, 193,  70,  29, 394,  37,  32, 365, 102,
#        441,  88,  64, 151, 459, 225, 337, 171, 391, 443, 380,  11, 251,
#         31, 512, 482, 146,  20, 451,  40, 252, 471, 288, 442, 398, 392,
#        250, 369, 492, 192,  82, 275,  13,  48,  63,  14, 356, 491, 507,
#        389, 309, 182, 148, 266, 257, 461, 130, 211, 332,  62, 157, 402,
#        470, 428,  57, 424, 464,  65, 173, 379, 249, 289, 255, 301, 140,
#         45, 296, 149, 433, 397, 231, 342, 475, 307,  39,  24, 285,   8,
#         91,   9, 265, 463,  95, 159, 395, 341, 345, 411, 164, 237, 287,
#        168, 127,  80,  42, 156,  68,  89, 427,  90, 120, 518, 222, 245,
#        448, 431,  76,  23, 235, 387, 416, 454, 355, 458, 292, 205, 128,
#        493, 489, 357, 346, 107, 456, 131, 406, 209, 116, 113,  56, 490,
#         27, 201, 167,  22,  18, 299, 504,   2, 279, 253, 166, 123,  53,
#        501,  59, 203, 228,  25, 312, 520, 500, 414,  73,  92, 348, 170,
#        423,  30, 226, 328, 446, 310, 495, 274,   3, 494, 325, 110, 455,
#         17, 425,  15, 437, 217,  44, 175, 516, 103, 190, 100, 467, 122,
#        114, 354, 333, 194, 121, 197, 141, 169, 351, 243, 408,  75, 371,
#        373, 480, 221, 153, 422, 426, 412, 248, 360,  81, 254, 162,  21,
#        263, 497, 505,   7, 115, 503,  97, 509, 383, 447, 163, 154, 335,
#        436,  34, 135, 483, 261, 236, 138, 466, 421, 241, 487, 124, 473,
#        196, 465, 496, 318, 143, 195, 305, 280, 396, 347, 308, 388, 134,
#        229, 515, 283, 213, 142, 282,  79, 277, 343, 317, 185, 435, 204,
#          4,  47, 259, 129, 177, 386, 242, 358, 353,  72, 486, 273, 478,
#        326, 450, 316, 216, 378, 269, 270, 472, 137, 239, 344, 330, 152,
#        469, 485, 262, 210, 468, 178, 320, 364,   0, 165, 453, 462, 272,
#        223, 519, 155, 323,  99, 477, 232,  46, 224,  74, 187,  83, 362,
#        484, 314, 126, 319,   6,  28, 284, 133, 290, 404, 218,  66, 230,
#        506, 268, 488, 359, 440, 322, 438, 247, 363, 502, 108, 432, 336,
#        267, 176, 214, 481, 382, 207,  98, 361,   5,  49, 202, 350,  10,
#        158, 161, 377, 368, 132, 420, 499, 240, 321,  41, 409, 200, 260,
#        352,  87, 181, 234, 215,  43, 367, 106, 160, 186, 212, 281, 227,
#        370, 109, 452, 278,  85, 276, 417, 184, 418, 119, 297, 315, 118,
#        374, 430, 513, 206, 419, 125,  38, 381, 199, 385, 295, 349, 415,
#        429], dtype=int64)

# %%
s_max_ix2 = np.argsort(S, axis=1)[:,::-1][:,:10]
s_max_ix_2 = s_max_ix2[s_max_ix1[:40],:5]
s_max_ix_2
# np.argsort(S[s_max_ix1[:5],:], axis=1)[:, ::-1][:,:10]
# Out:
# array([[395, 330,  36, 385, 205],
#        [109, 181, 139, 119, 229],
#        [350, 352, 351, 353, 223],
#        [187, 317, 319, 148, 318],
#        [227, 178, 341, 256, 294],
#        [102, 326, 144, 124,   9],
#        [156, 287, 283, 290, 176],
#        [ 50, 304,  47,   8, 376],
#        [305, 177, 153,   4, 173],
#        [305, 177, 153,   4, 173],
#        [144, 124, 326, 256, 102],
#        [305, 177, 153, 173,   4],
#        [156, 290, 287, 283, 176],
#        [305, 153, 177, 173,   4],
#        [102, 326, 144, 124,   9],
#        [306, 136, 116, 367, 329],
#        [305, 177, 153, 173,   4],
#        [304,  50,  47,   8, 376],
#        [156, 287, 290, 283, 176],
#        [210, 127,  14, 357, 309],
#        [305, 153, 173, 177,   4],
#        [116, 136,   5, 313, 112],
#        [156, 287, 283, 290, 176],
#        [289, 286, 281, 186, 176],
#        [305, 153, 173, 177,   4],
#        [254, 348, 244, 251,   7],
#        [144, 124, 326, 256,  70],
#        [326, 144, 124, 256,  70],
#        [156, 283, 290, 287, 286],
#        [223, 386, 352, 353, 225],
#        [305, 153, 177, 173,   4],
#        [304,  50,  47,   8, 376],
#        [188, 283, 287, 290, 156],
#        [116, 136, 306, 313,   5],
#        [156, 326, 124, 144, 287],
#        [305, 177, 153,   4, 173],
#        [116, 136, 306, 313,   5],
#        [138, 118, 354,  31, 200],
#        [  5, 313, 398, 171,  40],
#        [138, 118, 354,  31, 200]], dtype=int64)

# %%
np.sort(s_max)[::-1][:25]
# Out:
# array([0.99299726, 0.99155249, 0.99142063, 0.99135886, 0.99118032,
#        0.99074869, 0.9904682 , 0.99042703, 0.98942798, 0.98912912,
#        0.98870864, 0.98765552, 0.98705571, 0.98675731, 0.98670599,
#        0.9858651 , 0.98551555, 0.98551458, 0.98544207, 0.9851123 ,
#        0.98471525, 0.98470804, 0.9843199 , 0.98424867, 0.98410548])

# %%
tracks_df_1.iloc[s_max_ix1[:20],:]
# Out:
#      artist_name               artist_id  \
# 101  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 208  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 233  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 94   The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 105  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 498  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 410  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 405  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 331  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 508  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 340  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 399  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 444  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 294  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 60   The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 313  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 136  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 517  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 219  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
# 189  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
#
#                                             track_name                track_id
# 101                           Polythene Pam - 2019 Mix  7BavH3tDEsEDKnntiVTaAu
# 208                         Birthday - Remastered 2009  1ABegtCPBMMJaMpfDyATjE
# 233  Sgt. Pepper's Lonely Hearts Club Band - Repris...  42ocGQCOT0xYtV3f5kJDsD
# 94                         Octopus's Garden - 2019 Mix  3e1w0Wm0sH8nUYPArDkBG3
# 105                                 The End - 2019 Mix  481payDhvwK4SluEdw2o5v
# 498                         Get Back - Remastered 2009  3d5v5scfknhlp6oOC7BZBs
# 410                       Penny Lane - Remastered 2015  7afyyi8zn4FzWbcJ70F56V
# 405                      Day Tripper - Remastered 2015  29b2b96jozyD9GPCkOrVLs
# 331               A Hard Day's Night - Remastered 2009  5J2CHimS7dWYMImCHkEFaJ
# 508               A Hard Day's Night - Remastered 2009  1E4FcSqQs7U2RTebCNaYRH
# 340             Things We Said Today - Remastered 2009  0voUr8lubIafUVJlauJxYF
# 399               A Hard Day's Night - Remastered 2015  1pctwlBtIcKIjQMzsVcGHB
# 444              12 Bar Original - Anthology 2 Version  2HvTGx5fzFGpHSyRNvXd9T
# 294                         The Word - Remastered 2009  4GBaPHvAyj4V2jeobD9tsy
# 60             Get Back - Rooftop Performance / Take 1  4bVT9bpThKnkFtl1xeB2bh
# 313             Tell Me What You See - Remastered 2009  2jnr9KaaMAmvk0zMcM9UzV
# 136                                 Think For Yourself  0JRBoJ0LwENEiSqaaqbEeG
# 517                      Day Tripper - Remastered 2009  3hNUYt4dMM9RhcWmty8oKF
# 219                       Penny Lane - Remastered 2009  1h04XMpzGzmAudoI6VHBgA
# 189                It's All Too Much - Remastered 2009  2bQZ9BBhP7vSBiyDz7KXnv

# %%
tracks_df_2.iloc[s_max_ix_2[2], :]
# Out:
#                artist_name               artist_id  \
# 350  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 352  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 351  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 353  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 223  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
#
#                                     track_name                track_id
# 350               Out Of Control - Sasha Remix  6lxMmFyXLxgLbxNpJ5Lmt6
# 352            Out Of Control - Sasha Club Mix  3j6BOTtzPBSkmr5dEknhk7
# 351  Out Of Control - Sasha Remix / Radio Edit  0h19gBDFOK8lKmHSLAXgTK
# 353        Out Of Control - Sasha Instrumental  7cZOkHru5oFXZUMByjwiS5
# 223                             Chico's Groove  7JzD3lTV3bWCceb9A1DroB

# %%
#https://open.spotify.com/track/5vtRk4rYxiy4cj95cmJ5Ma?si=52adadf2bcd74639
#https://open.spotify.com/track/2wnsBaxrmkthIFAm6vqCuX?si=72c49a5c59c44ea3
#https://open.spotify.com/track/00oZhqZIQfL9P5CjOP6JsO?si=2ca72b174a2b40cb

track_inspect = 'Setting Sun'
print(tracks_df_2[tracks_df_2.track_name==track_inspect])
track_ix = tracks_df_2[tracks_df_2.track_name==track_inspect].index
audio_feats_df_2.iloc[track_ix, :]
# Out:
#                artist_name               artist_id   track_name  \
# 15   The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo  Setting Sun
# 145  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo  Setting Sun
# 211  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo  Setting Sun
# 379  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo  Setting Sun
#
#                    track_id
# 15   6yw35eTaS04QFe5PSirX9Z
# 145  4Yb8mY1J1nDwrhRlhCa9DS
# 211  5JBGbFdBtLcCCygw8rtjli
# 379  0Pi9gXX8JPKGD6kbUPYEPw
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 15   135.034    0.231     0.353            0.1330      0.000665        0.212
# 145  135.041    0.191     0.367            0.0543      0.000401        0.142
# 211  135.041    0.248     0.354            0.1300      0.000738        0.223
# 379  135.041    0.248     0.354            0.1300      0.000738        0.223
#
#      mode  loudness  key  energy  danceability
# 15      1    -1.175    0   0.995         0.447
# 145     1    -1.594    0   0.988         0.412
# 211     1    -1.169    0   0.995         0.446
# 379     1    -1.169    0   0.995         0.446

# %%
tracks_df_1[tracks_df_1.track_id == '00oZhqZIQfL9P5CjOP6JsO']
# Out:
#      artist_name               artist_id  \
# 288  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
#
#                                  track_name                track_id
# 288  Tomorrow Never Knows - Remastered 2009  00oZhqZIQfL9P5CjOP6JsO

# %%
track_inspect = 'Tomorrow Never Knows - Remastered 2009'
print(tracks_df_1[tracks_df_1.track_name==track_inspect])
track_ix = tracks_df_1[tracks_df_1.track_name==track_inspect].index[0]
check_ix = np.argsort(S[track_ix])[::-1][:20]
S[track_ix,check_ix]
# tracks_df_1[tracks_df_1.track_name==track_inspect]
# Out:
#      artist_name               artist_id  \
# 288  The Beatles  3WrFJ7ztbogyGnTHbHJFl2
#
#                                  track_name                track_id
# 288  Tomorrow Never Knows - Remastered 2009  00oZhqZIQfL9P5CjOP6JsO
# array([0.96424582, 0.95699015, 0.95121566, 0.94360369, 0.93358236,
#        0.93072345, 0.92823397, 0.92472016, 0.92472016, 0.92459084,
#        0.92375737, 0.92293121, 0.91460783, 0.91460783, 0.91460783,
#        0.91460783, 0.91460783, 0.90556114, 0.90508402, 0.90419266])

# %%
audio_feats_df_1.loc[[track_ix], :]
# Out:
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 288  125.887   0.0534     0.342           0.00208      0.000084       0.0405
#
#      mode  loudness  key  energy  danceability
# 288     1    -6.105    0   0.829          0.38

# %%
tracks_df_2.iloc[check_ix,:]
# Out:
#                artist_name               artist_id  \
# 145  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 191  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 55   The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 228  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 254  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 15   The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 348  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 379  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 211  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 125  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 378  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 89   The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 251  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 248  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 244  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 239  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 7    The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 329  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 243  The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
# 4    The Chemical Brothers  1GhPHrq36VKCY3ucVaZCfo
#
#                                             track_name                track_id
# 145                                        Setting Sun  4Yb8mY1J1nDwrhRlhCa9DS
# 191                                           The Test  0VfSNKmz24yn5idNxrvV10
# 55                                                 MAH  6Qk5eA59RBcO1bBkq9uSZM
# 228                    Hey Boy Hey Girl - ARTBAT Remix  6eCGHBR1irzeSUdOLuqV6J
# 254   Skipping Like A Stone (feat. Beck) - Single Edit  0yDcwwXLe0mTV2U5M4t0C4
# 15                                         Setting Sun  6yw35eTaS04QFe5PSirX9Z
# 348                        Out Of Control - Radio Edit  2QDnIFKbJZOK3LK2KqykM4
# 379                                        Setting Sun  0Pi9gXX8JPKGD6kbUPYEPw
# 211                                        Setting Sun  5JBGbFdBtLcCCygw8rtjli
# 125                Setting Sun - 2003 Digital Remaster  3HJy3DZZ6wAYQZ4SDK1YKQ
# 378                           Setting Sun - Radio Edit  4jgTeDwcvLdGtMhvgojIvD
# 89                                  Quayside Synthesis  0qpX5I9Xehi7onC9m1hxXK
# 251                 Skipping Like A Stone (feat. Beck)  7JpclywOpe1Vthr9TPdkj2
# 248                 Skipping Like A Stone (feat. Beck)  02WQIQSWjozbDeL5KAQ8Sq
# 244                 Skipping Like A Stone (feat. Beck)  2ww4PswNUUYizfZ3uJAVA1
# 239                 Skipping Like A Stone (feat. Beck)  5GRID4IlR1li1apKA4lg7T
# 7                   Skipping Like A Stone (feat. Beck)  6yjhWDg1b5YW3Vkr52Mf4L
# 329                                    The Test - Edit  4eC7E7ilCdA7EeyXv6UbEa
# 243  Skipping Like A Stone (feat. Beck) - Extended Mix  4btsTRXHobMFh3T2yNi9V3
# 4                                            Fountains  6VBFpHKhpBDfpjAcSOISoH

# %%
audio_feats_df_2.iloc[check_ix, :]
# Out:
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 145  135.041   0.1910    0.3670           0.05430      0.000401       0.1420
# 191  117.412   0.2940    0.1660           0.35500      0.006210       0.0530
# 55   129.947   0.2120    0.3460           0.23800      0.029600       0.0617
# 228  125.974   0.2540    0.1200           0.37200      0.000777       0.0706
# 254  127.983   0.1810    0.3620           0.00423      0.088100       0.0512
# 15   135.034   0.2310    0.3530           0.13300      0.000665       0.2120
# 348  131.990   0.3370    0.3090           0.02360      0.002190       0.0350
# 379  135.041   0.2480    0.3540           0.13000      0.000738       0.2230
# 211  135.041   0.2480    0.3540           0.13000      0.000738       0.2230
# 125  135.041   0.1910    0.3670           0.05430      0.000401       0.1420
# 378  135.053   0.1980    0.3740           0.06740      0.000392       0.1440
# 89   111.941   0.0394    0.2420           0.56600      0.080200       0.0394
# 251  128.045   0.2500    0.0750           0.00382      0.071200       0.0511
# 248  128.045   0.2500    0.0750           0.00382      0.071200       0.0511
# 244  128.045   0.2500    0.0750           0.00382      0.071200       0.0511
# 239  128.045   0.2500    0.0750           0.00382      0.071200       0.0511
# 7    128.045   0.2500    0.0750           0.00382      0.071200       0.0511
# 329  119.097   0.4200    0.0496           0.11600      0.006690       0.0660
# 243  128.005   0.2100    0.0580           0.06550      0.012400       0.0351
# 4    107.020   0.5090    0.2420           0.08700      0.124000       0.0408
#
#      mode  loudness  key  energy  danceability
# 145     1    -1.594    0   0.988         0.412
# 191     1    -3.965    0   0.879         0.297
# 55      1    -6.083    0   0.927         0.688
# 228     1    -3.563    0   0.965         0.546
# 254     1    -6.733    5   0.780         0.452
# 15      1    -1.175    0   0.995         0.447
# 348     0    -3.594    5   0.943         0.528
# 379     1    -1.169    0   0.995         0.446
# 211     1    -1.169    0   0.995         0.446
# 125     1    -1.594    7   0.988         0.412
# 378     1    -1.602    7   0.990         0.405
# 89      1    -5.972    0   0.815         0.627
# 251     1    -7.129    5   0.798         0.460
# 248     1    -7.129    5   0.798         0.460
# 244     1    -7.129    5   0.798         0.460
# 239     1    -7.129    5   0.798         0.460
# 7       1    -7.129    5   0.798         0.460
# 329     0    -4.006    7   0.897         0.309
# 243     1    -8.499    5   0.746         0.550
# 4       1    -7.215    0   0.710         0.769

# %%
# CIRCLE_OF_FIFTHS = [0, 7, 2, 9, 4, 11, 6, 1, 8, 3, 10, 5]
audio_feats_df_2[audio_feats_df_2.key.isin([11, 6, 1])].sort_values(['key', 'tempo'])
# Out:
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 293   72.378   0.0855    0.2630          0.000530      0.007190       0.1180
# 119   77.495   0.0817    0.9280          0.002620      0.638000       0.0537
# 252  103.284   0.0330    0.8040          0.936000      0.845000       0.2190
# 136  119.967   0.5820    0.8930          0.023900      0.000252       0.0362
# 64   144.499   0.6230    0.9520          0.000801      0.123000       0.0312
# 87   151.974   0.3360    0.9390          0.000361      0.006210       0.0517
# 14   159.050   0.3780    0.1570          0.000000      0.371000       0.1660
# 142  160.131   0.5430    0.9810          0.008640      0.020900       0.1050
# 58   160.177   0.6840    0.9580          0.350000      0.002890       0.0649
# 127  178.082   0.3630    0.9090          0.004120      0.000279       0.1760
# 90    88.013   0.2240    0.9440          0.013200      0.059300       0.0510
# 48    89.902   0.3550    0.7340          0.004610      0.279000       0.0305
# 42    93.365   0.0572    0.1310          0.485000      0.638000       0.0342
# 280   98.042   0.1220    0.1830          0.060500      0.208000       0.0321
# 202  108.012   0.6970    0.9200          0.007710      0.024800       0.0602
# 126  129.017   0.2010    0.9900          0.017600      0.000070       0.0639
# 289  136.027   0.6970    0.1280          0.000000      0.005550       0.0348
# 173  145.088   0.1330    0.9910          0.000624      0.007980       0.1100
# 134  159.996   0.6290    0.9890          0.300000      0.003250       0.0599
# 33   178.958   0.2670    0.2390          0.000000      0.047100       0.1180
# 167   78.392   0.1580    0.3160          0.000091      0.707000       0.0919
# 232   81.355   0.0393    0.9660          0.894000      0.723000       0.0377
# 212   84.632   0.0384    0.9870          0.875000      0.836000       0.0325
# 81    87.981   0.3500    0.7320          0.000050      0.087100       0.0441
# 84    89.000   0.7490    0.8300          0.000044      0.014500       0.0707
# 60    89.076   0.4690    0.8510          0.000042      0.266000       0.0290
# 37    96.350   0.0390    0.4890          0.901000      0.810000       0.0326
# 267   97.582   0.4850    0.1950          0.000194      0.124000       0.0535
# 277   97.640   0.5910    0.3890          0.000840      0.781000       0.0343
# 300  104.169   0.1160    0.0757          0.048700      0.386000       0.0276
# 121  107.966   0.4060    0.9980          0.000039      0.018300       0.0305
# 139  108.045   0.5740    0.9760          0.005090      0.015600       0.0307
# 176  112.046   0.3550    0.9810          0.026100      0.388000       0.0682
# 285  119.876   0.1720    0.0967          0.000053      0.034100       0.0490
# 241  127.267   0.6330    0.9750          0.058500      0.107000       0.0723
# 255  128.060   0.7460    0.9840          0.000717      0.047600       0.0557
# 259  130.030   0.6960    0.3710          0.000220      0.152000       0.0498
# 1    131.538   0.6250    0.1330          0.060100      0.894000       0.0848
# 160  137.612   0.3380    0.1910          0.000000      0.028200       0.0601
# 32   140.703   0.5020    0.3570          0.000017      0.000184       0.0544
# 125  150.020   0.2760    0.9320          0.001570      0.011500       0.0645
# 145  150.038   0.2540    0.9850          0.035500      0.001050       0.0640
# 248  150.342   0.4790    0.9790          0.000000      0.287000       0.2090
# 35   150.417   0.5200    0.6620          0.035400      0.000492       0.1380
# 124  159.979   0.3740    0.9840          0.157000      0.051200       0.0876
# 78   165.962   0.4700    0.9260          0.000246      0.004610       0.1560
# 283  170.206   0.3760    0.5800          0.018300      0.024500       0.0979
# 143  178.033   0.4280    0.9780          0.002030      0.002230       0.3740
#
#      mode  loudness  key  energy  danceability
# 293     1    -5.983    1   0.844         0.335
# 119     1   -13.518    1   0.495         0.294
# 252     1   -24.710    1   0.551         0.232
# 136     0    -8.981    1   0.826         0.527
# 64      1    -8.788    1   0.700         0.412
# 87      0    -8.531    1   0.884         0.525
# 14      1    -7.165    1   0.773         0.253
# 142     1    -9.852    1   0.830         0.633
# 58      1    -9.814    1   0.897         0.538
# 127     0    -9.186    1   0.909         0.411
# 90      0   -12.789    6   0.567         0.702
# 48      1   -11.430    6   0.601         0.547
# 42      0   -14.627    6   0.211         0.110
# 280     1    -9.203    6   0.525         0.364
# 202     0    -8.382    6   0.907         0.570
# 126     0    -8.359    6   0.962         0.535
# 289     0    -4.798    6   0.842         0.518
# 173     0    -9.963    6   0.933         0.202
# 134     0   -10.532    6   0.770         0.582
# 33      1    -7.354    6   0.608         0.378
# 167     1   -11.577   11   0.370         0.497
# 232     1   -15.205   11   0.393         0.263
# 212     1   -17.572   11   0.153         0.110
# 81      0    -8.164   11   0.609         0.686
# 84      1    -9.310   11   0.872         0.601
# 60      1   -10.161   11   0.548         0.575
# 37      1   -14.033   11   0.196         0.122
# 267     0    -8.086   11   0.676         0.394
# 277     0   -11.464   11   0.421         0.655
# 300     1    -9.190   11   0.466         0.367
# 121     1    -8.786   11   0.746         0.518
# 139     1    -9.221   11   0.675         0.560
# 176     1    -9.282   11   0.933         0.424
# 285     0    -7.116   11   0.725         0.481
# 241     0    -7.212   11   0.934         0.585
# 255     0    -7.649   11   0.832         0.466
# 259     0    -8.300   11   0.856         0.447
# 1       0    -9.181   11   0.812         0.738
# 160     0    -6.648   11   0.797         0.234
# 32      0    -4.993   11   0.915         0.261
# 125     0   -10.111   11   0.941         0.416
# 145     0    -9.988   11   0.931         0.538
# 248     0    -6.752   11   0.958         0.291
# 35      0    -5.633   11   0.917         0.239
# 124     0    -9.543   11   0.906         0.497
# 78      1    -8.629   11   0.874         0.324
# 283     0    -5.695   11   0.868         0.371
# 143     1    -9.883   11   0.906         0.424

# %%
tracks_df_2[audio_feats_df_2.key.isin([11, 6, 1])]
# Out:
#      artist_name               artist_id  \
# 1    David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 14   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 32   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 33   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 35   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 37   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 42   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 48   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 58   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 60   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 64   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 78   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 81   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 84   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 87   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 90   David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 119  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 121  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 124  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 125  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 126  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 127  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 134  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 136  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 139  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 142  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 143  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 145  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 160  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 167  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 173  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 176  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 202  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 212  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 232  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 241  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 248  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 252  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 255  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 259  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 267  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 277  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 280  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 283  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 285  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 289  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 293  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
# 300  David Bowie  0oSGxfWSnnOXhD2fKuz2Gy
#
#                                             track_name                track_id
# 1                           Hang On To Yourself - Demo  5vv4Fn4G4fc1uuaDg3lhyc
# 14   Ziggy Stardust - Sounds Of The 70s: John Peel ...  3dc9UYPzC1wsWGx7VGKSmI
# 32   All The Young Dudes (Live) [Stereo] - Live; St...  2lS36OEks0Zc7vdt7lk5ej
# 33   Oh! You Pretty Things (Live) [Stereo] - Live; ...  3RWc7T8yFuEnTPAGrg7wZ1
# 35     Moonage Daydream (Live) [Stereo] - Live; Stereo  2o98fGp4t5bNIS6ky0xa6u
# 37               Warszawa - Live Moonage Daydream Edit  4xScGPuPY1KXTUtofpmeZg
# 42                       Subterraneans - 2017 Remaster  7sPFp70VxgvrZVorzVBtSD
# 48   Thursday's Child - Live at the Kit Kat Klub, N...  3b535uOV5AVOtDdAICJuFz
# 58   I’m Afraid Of Americans - Live at the Kit Kat ...  5DdO7Bg3KB5KyzXJTv2XR7
# 60   Thursday's Child - Live at the Elysée Montmart...  5KEdsAcV9pm7AK8v4VxAeC
# 64   China Girl - Live at the Elysée Montmartre, Pa...  6XZIVWKcpoABI7h7ugz06V
# 78   Battle for Britain (The Letter) - Live at the ...  4FfFQ0PYAPUeFknoEuUyH2
# 81   Fame - Live at the Phoenix Festival, Long Mars...  6rnPeQHMKlp0dCzYvClwxG
# 84   The Hearts Filthy Lesson - Live at the Phoenix...  3XWzlDIuMHPqmWRLfZNh1C
# 87   Little Wonder - Live at the Phoenix Festival, ...  0H4yvSH0waTu1zJ0yCocIu
# 90   O Superman - Live at the Phoenix Festival, Lon...  0TCiV2bgBSQyEPtNyybL2g
# 119  The Motel - Live at the National Exhibition Ce...  7FLMrK0hqldqJLMJU5h0uL
# 121  Teenage Wildlife - Live at the National Exhibi...  7INQNlmtZRMyjjLtBW4zIV
# 124  We Prick You - Live at the National Exhibition...  640oHOQrEfa3fhEoHMucHe
# 125  Hallo Spaceboy (Version 2) - Live at the Natio...  3WOt2baurnIrR5QDLF7MeH
# 126  Look Back In Anger - Live at the Starplex Amph...  1o0CbcLSQMrLpV9UYJ3Sl8
# 127  The Hearts Filthy Lesson - Live at the Starple...  0sFxwShUbXbIhunahmv75O
# 134  We Prick You - Live at the Starplex Amphitheat...  03OhKgAxUCT5elMhSUOx7t
# 136  Joe The Lion - Live at the Starplex Amphitheat...  4oH5ysOKx0hnBWf6nZi8dE
# 139  Teenage Wildlife - Live at the Starplex Amphit...  11eU9U5xm91DerN5phrUXT
# 142  I'm Afraid Of Americans - Live at Radio City M...  0R0ha0Me3ayJh1s0nPtwT1
# 143  The Hearts Filthy Lesson - Live at Long Marsto...  0yc7eSSEcVwotWCl0GZGpO
# 145  Hallo Spaceboy - Live from Rio de Janeiro, Met...  5f85sYqc0OG18KvIDFAVRN
# 160                       She Shook Me Cold - 2020 Mix  1JOCQudJt0rveB8vBnw1Fe
# 167  Ching-a-Ling (with John 'Hutch' Hutchinson) - ...  1nNKLpRCZ82LiHHdfyI6H4
# 173       Look Back In Anger - Live '83, 2018 Remaster  3fwTt94r9FLXoREZ5fwILx
# 176             Golden Years - Live '83, 2018 Remaster  3s4lXdIjWAi34SV5Lu3vlN
# 202             Golden Years - Live, Glastonbury, 2000  7vOlYjKm47NGjA9kANMbZF
# 212                                    Warszawa - Live  1Jc6ZpHIhXZLguEC923ZQs
# 232                     Warszawa - Live; 2017 Remaster  2lcEd2UqtaBHjZlScPYfFg
# 241         Beauty and the Beast - Live; 2017 Remaster  3ihf8RLum5OO4k6GsWZgqv
# 248                            Suffragette City - Live  0fwA2jyiLvySDLqZwu7val
# 252                                Introduction - Live  1AoqG95GUqeSHdeZcxXRDK
# 255                            Moonage Daydream - Live  7sbkkXctrVzrSkscfzXfkM
# 259                                Aladdin Sane - Live  1dmpmjx3VD2JNMoqlDCkxm
# 267                                 Big Brother - Live  59tl4yZfJRP5QJEILhLlzZ
# 277                                        Fame - Live  6LUuE3MQMKYwbonbZYuE4v
# 280                                                  ★  1Xb5UAKg5OdTHkg48FdQou
# 283                      Sue (Or In A Season Of Crime)  0DEslRB6ry2swHIY0aaNzY
# 285                                        Dollar Days  1k5GEEuEoBiklGgmQcD62s
# 289                        The Stars (Are Out Tonight)  1nRynODR7IrQMp54k3l24h
# 293                                  If You Can See Me  09HXSK6uNXKGQM0kfEnhOZ
# 300                                               Heat  73CNPdDGbgWNnl2MzmdXJw

# %%
tracks_df_1[tracks_df_1.track_name=='Neighborhood #1 (Tunnels)']
audio_feats_df_1[tracks_df_1.track_name=='Neighborhood #1 (Tunnels)']
# Out:
#        tempo  valence  liveness  instrumentalness  acousticness  speechiness  \
# 112  126.914    0.211      0.29            0.0142        0.0647       0.0324
#
#      mode  loudness  key  energy  danceability
# 112   1.0    -5.566  0.0   0.738         0.282

# %%
tracks_df_2[tracks_df_2.track_name.str.contains('Hero')]
# audio_feats_df_2[tracks_df_2.track_name=='Neighborhood #1 (Tunnels)']
(tracks_df_2.track_id == '7Jh1bpe76CNTCgdgAdBw4Z').sum()
# Out:
# 0
